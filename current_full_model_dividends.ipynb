# %%
import pandas as pd
from database.market import Market
from database.sec import SEC
from database.adatabase import ADatabase
from processor.processor import Processor as p
from datetime import datetime
from tqdm import tqdm
import numpy as np
from modeler_strats.universal_modeler import UniversalModeler
import pickle

# %%
current_year = 2023

# %%
market = Market()
spec = ADatabase("dividends")
umod = UniversalModeler()
sec = SEC()

# %%
market.connect()
sp500 = market.retrieve("sp500")
market.disconnect()
sp500 = sp500.rename(columns={"Symbol":"ticker"})

# %%
factors = ['assets',
 'liabilitiesandstockholdersequity',
 'incometaxexpensebenefit',
 'retainedearningsaccumulateddeficit',
 'accumulatedothercomprehensiveincomelossnetoftax',
 'earningspersharebasic',
 'earningspersharediluted',
 'propertyplantandequipmentnet',
 'cashandcashequivalentsatcarryingvalue',
 'entitycommonstocksharesoutstanding',
 'weightedaveragenumberofdilutedsharesoutstanding',
 'weightedaveragenumberofsharesoutstandingbasic',
 'stockholdersequity',
"commonstockdividendspersharecashpaid"]

# %%
included_columns=[
    "year",
    "week",
    "ticker",
    "adjclose",
    "y"
]

# %%
included_columns.extend(factors)

# %%
training_sets = []

# %%
sec.connect()
market.connect()
for ticker in sp500["ticker"].unique():
    try:
        cik = int(sp500[sp500["ticker"]==ticker]["CIK"])
        prices = market.retrieve_ticker_prices("prices",ticker)
        prices = p.column_date_processing(prices)
        prices["year"] = [x.year for x in prices["date"]]
        prices["quarter"] = [x.quarter for x in prices["date"]]
        filing = sec.retrieve_filing_data(cik)
        filing = p.column_date_processing(filing)
        filing = filing.groupby(["year","quarter"]).mean().reset_index()
        ticker_data = prices.copy()
        ticker_data.sort_values("date",ascending=True,inplace=True)
        ticker_data["adjclose"] = [float(x) for x in ticker_data["adjclose"]]
        ticker_data = ticker_data.groupby(["year","quarter"]).mean().reset_index()
        ticker_data.dropna(inplace=True)
        ticker_data["ticker"] = ticker
        ticker_data = ticker_data.merge(filing,on=["year","quarter"],how="left").reset_index()
        ticker_data["y"] = ticker_data["adjclose"].shift(-4) + ticker_data["commonstockdividendspersharecashpaid"]
        ticker_data = ticker_data[included_columns]
        training_sets.append(ticker_data)
    except Exception as e:
        print(ticker,str(e))
sec.disconnect()
market.disconnect()
# Out:
# ABT 'commonstockdividendspersharecashpaid'
# ABMD 'commonstockdividendspersharecashpaid'
# ACN "['entitycommonstocksharesoutstanding'] not in index"
# ATVI 'commonstockdividendspersharecashpaid'
# ADM "['stockholdersequity'] not in index"
# ADBE 'commonstockdividendspersharecashpaid'
# ADP 'commonstockdividendspersharecashpaid'
# AAP 'commonstockdividendspersharecashpaid'
# APD 'commonstockdividendspersharecashpaid'
# AKAM 'commonstockdividendspersharecashpaid'
# ALB 'commonstockdividendspersharecashpaid'
# ARE 'commonstockdividendspersharecashpaid'
# ALGN 'commonstockdividendspersharecashpaid'
# ALL "['cashandcashequivalentsatcarryingvalue'] not in index"
# GOOGL 'commonstockdividendspersharecashpaid'
# AMZN 'commonstockdividendspersharecashpaid'
# AMCR 'commonstockdividendspersharecashpaid'
# AMD 'commonstockdividendspersharecashpaid'
# AEP 'commonstockdividendspersharecashpaid'
# AXP 'commonstockdividendspersharecashpaid'
# AIG "['cashandcashequivalentsatcarryingvalue'] not in index"
# AMP 'commonstockdividendspersharecashpaid'
# ANSS 'commonstockdividendspersharecashpaid'
# SWKS 'commonstockdividendspersharecashpaid'
# SJM 'commonstockdividendspersharecashpaid'
# SEDG 'commonstockdividendspersharecashpaid'
# SWK 'commonstockdividendspersharecashpaid'
# STT 'commonstockdividendspersharecashpaid'
# SYK 'commonstockdividendspersharecashpaid'
# SYF 'commonstockdividendspersharecashpaid'
# SNPS 'commonstockdividendspersharecashpaid'
# SYY 'commonstockdividendspersharecashpaid'
# TMUS 'commonstockdividendspersharecashpaid'
# TROW 'commonstockdividendspersharecashpaid'
# TTWO 'commonstockdividendspersharecashpaid'
# TPR 'commonstockdividendspersharecashpaid'
# TGT 'commonstockdividendspersharecashpaid'
# TDY 'commonstockdividendspersharecashpaid'
# TFX 'commonstockdividendspersharecashpaid'
# TSLA 'commonstockdividendspersharecashpaid'
# TMO 'commonstockdividendspersharecashpaid'
# TJX 'commonstockdividendspersharecashpaid'
# TSCO 'commonstockdividendspersharecashpaid'
# TRV 'commonstockdividendspersharecashpaid'
# TRMB 'commonstockdividendspersharecashpaid'
# TFC 'commonstockdividendspersharecashpaid'
# TWTR 'commonstockdividendspersharecashpaid'
# TYL 'commonstockdividendspersharecashpaid'
# TSN 'commonstockdividendspersharecashpaid'
# USB 'commonstockdividendspersharecashpaid'
# UDR "['retainedearningsaccumulateddeficit', 'propertyplantandequipmentnet'] not in index"
# ULTA 'commonstockdividendspersharecashpaid'
# UAA 'commonstockdividendspersharecashpaid'
# UAL 'commonstockdividendspersharecashpaid'
# UPS "['entitycommonstocksharesoutstanding'] not in index"
# URI 'commonstockdividendspersharecashpaid'
# UHS "['entitycommonstocksharesoutstanding'] not in index"
# VTR "['propertyplantandequipmentnet'] not in index"
# VRSN 'commonstockdividendspersharecashpaid'
# VRSK 'commonstockdividendspersharecashpaid'
# VZ 'commonstockdividendspersharecashpaid'
# VRTX 'commonstockdividendspersharecashpaid'
# V "['earningspersharebasic', 'earningspersharediluted', 'entitycommonstocksharesoutstanding', 'weightedaveragenumberofdilutedsharesoutstanding', 'weightedaveragenumberofsharesoutstandingbasic', 'stockholdersequity'] not in index"
# VNO "['propertyplantandequipmentnet'] not in index"
# WBA 'commonstockdividendspersharecashpaid'
# WBD 'commonstockdividendspersharecashpaid'
# WAT 'commonstockdividendspersharecashpaid'
# WEC 'commonstockdividendspersharecashpaid'
# WFC 'commonstockdividendspersharecashpaid'
# WELL "['propertyplantandequipmentnet'] not in index"
# WST 'commonstockdividendspersharecashpaid'
# WDC 'commonstockdividendspersharecashpaid'
# WMB 'commonstockdividendspersharecashpaid'
# XEL 'commonstockdividendspersharecashpaid'
# YUM 'commonstockdividendspersharecashpaid'
# ZBRA 'commonstockdividendspersharecashpaid'
# ZBH 'commonstockdividendspersharecashpaid'
# ZION "['cashandcashequivalentsatcarryingvalue'] not in index"

# %%
data = pd.concat(training_sets)

# %%
data = data.dropna()

# %%
spec.connect()
for modeler in [umod]:
    for year in tqdm(range(current_year,current_year+1)):
        training_slice = data[(data["year"]<year) & (data["year"] >= year - 4)].reset_index(drop=True)
        set_name = "models"
        stuff = modeler.recommend_model(training_slice,factors,tf=False)
spec.disconnect()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:08<00:00,  8.58s/it]

# %%
stuff["model"] = [pickle.dumps(x) for x in stuff["model"]]

# %%
spec.connect()
models = spec.store("models",stuff)
spec.disconnect()
