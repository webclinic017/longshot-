# %%
from database.market import Market
from database.sec import SEC
from database.adatabase import ADatabase
import pandas as pd
import matplotlib.pyplot as plt
from processor.processor import Processor as p
from statistics import variance
from tqdm import tqdm
from modeler.modeler import Modeler as m
from datetime import datetime, timedelta

# %%
market = Market()
sec = SEC()

# %%
# market.connect()
# prices = market.retrieve("alpha_prices")
# market.disconnect()

# %%
fed_fund = pd.read_csv("./csv_files/FED/FEDFUNDS.csv")
spy = pd.read_csv("./csv_files/FED/SPY.csv")
gdp = pd.read_csv("./csv_files/FED/GDP.csv")
brent = pd.read_csv("./csv_files/FED/POILBREUSDM.csv")
wti = pd.read_csv("./csv_files/FED/POILWTIUSDM.csv")
cpi = pd.read_csv("./csv_files/FED/CPIAUCSL.csv")
unemployment = pd.read_csv("./csv_files/FED/UNRATE.csv")

# %%
datasets = {"spy":spy,
           "fed_fund":fed_fund,
           "gdp":gdp,
            "brent":brent,
            "wti":wti, 
            "cpi":cpi, 
            "unemployment":unemployment}

# %%
cleaned_sets = {}
for dataset in tqdm(datasets.keys()):
    try:
        cleaned = p.column_date_processing(datasets[dataset])
        cleaned["year"] = [x.year for x in cleaned["date"]]
        cleaned["quarter"] = [x.quarter for x in cleaned["date"]]
        cleaned.drop("week",axis=1,inplace=True)
        cleaned_quarterly = cleaned.groupby(["year","quarter"]).mean().reset_index()
        cleaned_sets[dataset] = cleaned_quarterly
    except Exception as e:
        print(str(e))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 159.06it/s]

# %%
base = cleaned_sets["spy"][["year","quarter","adjclose"]]
base.rename(columns={"adjclose":"spy"},inplace=True)

# %%
for dataset in cleaned_sets:
    if dataset == "spy":
        continue
    else:
        ds = cleaned_sets[dataset]
        base = base.merge(ds.drop("date",axis=1,errors="ignore"),on=["year","quarter"],how="left")

# %%
data = base.copy()

# %%
data.columns
# Out:
# Index(['year', 'quarter', 'spy', 'fedfunds', 'gdp', 'poilbreusdm',
#        'poilwtiusdm', 'cpiaucsl', 'unrate'],
#       dtype='object')

# %%
base["y"] = base["spy"].shift(-4)

# %%
base["date"] = [datetime(int(row[1]["year"]),int(row[1]["quarter"]-1) * 3 + 1,1) for row in base.iterrows()]

# %%
factors = [x for x in base.columns if x not in ["year","quarter","y","date"]]
factors
# Out:
# ['spy', 'fedfunds', 'gdp', 'poilbreusdm', 'poilwtiusdm', 'cpiaucsl', 'unrate']

# %%
base
# Out:
#     year  quarter         spy  fedfunds        gdp  poilbreusdm  poilwtiusdm  \
# 0   2018        1  250.379577  1.446667  20155.486    67.159150    62.880746
# 1   2018        2  249.122674  1.736667  20470.197    74.890021    68.029565
# 2   2018        3  263.790247  1.923333  20687.278    76.081132    69.730812
# 3   2018        4  250.940834  2.220000  20819.269    68.320070    58.620091
# 4   2019        1  254.382730  2.403333  21013.085    63.756896    54.797956
# 5   2019        2  270.719942  2.396667  21272.448    68.357847    59.758818
# 6   2019        3  279.147975  2.190000  21531.839    62.123769    56.355514
# 7   2019        4  292.263762  1.643333  21706.532    62.555384    56.835405
# 8   2020        1  290.961983  1.260000  21538.032    51.178989    45.881804
# 9   2020        2  280.831936  0.060000  19636.731    33.377157    28.023658
# 10  2020        3  319.365394  0.093333  21362.428    43.434633    40.894784
# 11  2020        4  343.268623  0.090000  21704.706    45.344592    42.621494
# 12  2021        1  374.677348  0.080000  22313.850    61.127783    57.755979
# 13  2021        2  406.855821  0.070000  23046.934    69.139928    65.985317
# 14  2021        3  431.381186  0.090000  23550.420    73.246970    70.666364
# 15  2021        4  450.420798  0.080000  24349.121    79.811318    77.420638
# 16  2022        1  438.321888  0.120000  24740.480    97.443127    94.428250
# 17  2022        2  404.610277  0.770000  25248.476   111.987359   108.791291
# 18  2022        3  393.955925  2.190000  25723.941    97.834694    93.336901
# 19  2022        4  382.871383  3.653333        NaN    92.328604    85.681515
# 20  2023        1  389.922995       NaN        NaN          NaN          NaN
#
#       cpiaucsl     unrate           y       date
# 0   249.254333   4.033333  254.382730 2018-01-01
# 1   250.681000   3.933333  270.719942 2018-04-01
# 2   251.770333   3.766667  279.147975 2018-07-01
# 3   252.690000   3.833333  292.263762 2018-10-01
# 4   253.292667   3.866667  290.961983 2019-01-01
# 5   255.283000   3.633333  280.831936 2019-04-01
# 6   256.225000   3.633333  319.365394 2019-07-01
# 7   257.785333   3.600000  343.268623 2019-10-01
# 8   258.618000   3.800000  374.677348 2020-01-01
# 9   256.418333  12.966667  406.855821 2020-04-01
# 10  259.437667   8.833333  431.381186 2020-07-01
# 11  260.879000   6.766667  450.420798 2020-10-01
# 12  263.524667   6.200000  438.321888 2021-01-01
# 13  268.760333   5.933333  404.610277 2021-04-01
# 14  273.163333   5.133333  393.955925 2021-07-01
# 15  278.413333   4.200000  382.871383 2021-10-01
# 16  284.607667   3.800000  389.922995 2022-01-01
# 17  291.821667   3.600000         NaN 2022-04-01
# 18  295.884000   3.566667         NaN 2022-07-01
# 19  298.174333   3.600000         NaN 2022-10-01
# 20         NaN        NaN         NaN 2023-01-01

# %%
sims = []
for year in tqdm(range(2022,2023)):
    try:
        training_set = base[(base["year"]<year) & (base["year"]>=year-7)].copy().reset_index()
        prediction_set = base[base["year"]==year].copy()
        spy_model = m.regression({"X":training_set[factors],"y":training_set[["y"]]})
        sim = prediction_set.fillna(method="ffill")
        for row in spy_model.iterrows():
            model = row[1]["model"]
            api = row[1]["api"]
            score = row[1]["score"]
            predictions = model.predict(sim[factors])
            sim[f"{api}_prediction"] = predictions
            sim[f"{api}_score"] = score
            sims.append(sim)
    except Exception as e:
        print(year,str(e))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.60s/it]

# %%
final_sim = pd.concat(sims)
final_sim["year"] = final_sim["year"] + 1

# %%
final_sim
# Out:
#     year  quarter         spy  fedfunds        gdp  poilbreusdm  poilwtiusdm  \
# 16  2023        1  438.321888  0.120000  24740.480    97.443127    94.428250
# 17  2023        2  404.610277  0.770000  25248.476   111.987359   108.791291
# 18  2023        3  393.955925  2.190000  25723.941    97.834694    93.336901
# 19  2023        4  382.871383  3.653333  25723.941    92.328604    85.681515
# 16  2023        1  438.321888  0.120000  24740.480    97.443127    94.428250
# 17  2023        2  404.610277  0.770000  25248.476   111.987359   108.791291
# 18  2023        3  393.955925  2.190000  25723.941    97.834694    93.336901
# 19  2023        4  382.871383  3.653333  25723.941    92.328604    85.681515
# 16  2023        1  438.321888  0.120000  24740.480    97.443127    94.428250
# 17  2023        2  404.610277  0.770000  25248.476   111.987359   108.791291
# 18  2023        3  393.955925  2.190000  25723.941    97.834694    93.336901
# 19  2023        4  382.871383  3.653333  25723.941    92.328604    85.681515
#
#       cpiaucsl    unrate           y       date  skl_prediction  skl_score  \
# 16  284.607667  3.800000  389.922995 2022-01-01      288.055438   0.830806
# 17  291.821667  3.600000  389.922995 2022-04-01      168.637047   0.830806
# 18  295.884000  3.566667  389.922995 2022-07-01      159.600645   0.830806
# 19  298.174333  3.600000  389.922995 2022-10-01      119.259587   0.830806
# 16  284.607667  3.800000  389.922995 2022-01-01      288.055438   0.830806
# 17  291.821667  3.600000  389.922995 2022-04-01      168.637047   0.830806
# 18  295.884000  3.566667  389.922995 2022-07-01      159.600645   0.830806
# 19  298.174333  3.600000  389.922995 2022-10-01      119.259587   0.830806
# 16  284.607667  3.800000  389.922995 2022-01-01      288.055438   0.830806
# 17  291.821667  3.600000  389.922995 2022-04-01      168.637047   0.830806
# 18  295.884000  3.566667  389.922995 2022-07-01      159.600645   0.830806
# 19  298.174333  3.600000  389.922995 2022-10-01      119.259587   0.830806
#
#     xgb_prediction  xgb_score  cat_prediction  cat_score
# 16      382.896179   0.720508      370.017348    0.82264
# 17      381.983185   0.720508      369.899264    0.82264
# 18      342.919220   0.720508      352.945099    0.82264
# 19      337.512817   0.720508      357.060037    0.82264
# 16      382.896179   0.720508      370.017348    0.82264
# 17      381.983185   0.720508      369.899264    0.82264
# 18      342.919220   0.720508      352.945099    0.82264
# 19      337.512817   0.720508      357.060037    0.82264
# 16      382.896179   0.720508      370.017348    0.82264
# 17      381.983185   0.720508      369.899264    0.82264
# 18      342.919220   0.720508      352.945099    0.82264
# 19      337.512817   0.720508      357.060037    0.82264

# %%
strat_db = ADatabase("strategy_econ")
strat_db.connect()
strat_db.store("sim",final_sim)
strat_db.disconnect()
