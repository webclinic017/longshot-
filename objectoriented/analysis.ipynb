# %%
from datetime import datetime, timedelta
import pytz
import pandas as pd
from tqdm import tqdm
from modeler.modeler import Modeler as m
from processor.processor import Processor as p
from database.market import Market
from database.adatabase import ADatabase
import numpy as np
import matplotlib.pyplot as plt
import pickle
import matplotlib.dates as mdates
import statistics
from fund.fund import Fund
from fund.states import States

# %%
market = Market()
save_parameters = False
fund = Fund("delta",States.BACKTEST)
fund.pull_portfolios()
fund.initialize_portfolios()

# %%
market.connect()
sp5 = market.retrieve("sp500")
market.disconnect()

# %%
startDate = datetime(2016,1,1)
endDate = datetime(2023,1,1)
starting_capital = 100000
trades = fund.pull_trades()
portfolios = fund.pull_portfolio_states()

# %%
pt = pd.concat(portfolios)

# %%
pt["positions"] = [pickle.loads(x) for x in pt["positions"]]

# %%
t = pd.concat(trades)

# %%
non_params = ["date","sell_date","ticker","adjclose","sell_price","delta","projected_delta","position","holding",'close',
 'high',
 'low',
 'open',
 'volume',
 'adjhigh',
 'adjlow',
 'adjopen',
 'adjvolume',
 'divcash',
 'splitfactor',
 'year',
 'week',
 'quarter',
 'prediction',
"buy_price","amount","pv",
"swap"]
parameter_columns = [x for x in t.columns if x not in non_params]

# %%
t["holding"] = [(row[1]["sell_date"] - row[1]["date"]).days for row in t.iterrows()]

# %%
parameter_columns
# Out:
# ['signal',
#  'req',
#  'value',
#  'oc',
#  'strategy',
#  'portfolio_type',
#  'modeler_type',
#  'diversifier_type']

# %%
iterations = t.groupby(parameter_columns).mean().reset_index()[parameter_columns]

# %%
iterations
# Out:
#     signal   req  value     oc     strategy portfolio_type modeler_type  \
# 0     0.05  0.05  False  False  speculation      universal     industry
# 1     0.05  0.05  False  False  speculation      universal     industry
# 2     0.05  0.05  False  False  speculation      universal    universal
# 3     0.05  0.05  False  False  speculation      universal    universal
# 4     0.05  0.05   True  False  speculation      universal     industry
# ..     ...   ...    ...    ...          ...            ...          ...
# 67    0.15  0.15  False  False  speculation      universal    universal
# 68    0.15  0.15   True  False  speculation      universal     industry
# 69    0.15  0.15   True  False  speculation      universal     industry
# 70    0.15  0.15   True  False  speculation      universal    universal
# 71    0.15  0.15   True  False  speculation      universal    universal
#
#    diversifier_type
# 0             basic
# 1          industry
# 2             basic
# 3          industry
# 4             basic
# ..              ...
# 67         industry
# 68            basic
# 69         industry
# 70            basic
# 71         industry
#
# [72 rows x 8 columns]

# %%
analysis = []
metric = "pv"
for row in iterations.iterrows():
    iteration_trades = t.copy()
    iteration_analysis = []
    for col in iterations.columns:
        param = row[1][col]
        iteration_trades = iteration_trades[(iteration_trades[col]==param)]
    positions = int(iteration_trades["position"].max())
    iteration_trades["delta"] = iteration_trades["delta"] + 1
    pivoted = iteration_trades.pivot_table(index="sell_date",columns="position",values="delta").fillna(1)
    for i in range(10):
        if i not in pivoted.columns:
            pivoted[i] = 1
    pivoted["pv"] = [sum([row[1][column] * 0.1 for column in range(10)]) for row in pivoted.iterrows()]
    pv = pivoted["pv"].cumprod().tail(1).item()
    current = row[1].to_dict()
    current["pv"] = pv
    analysis.append(current)

# %%
complete = pd.DataFrame(analysis)

# %%
complete.sort_values(metric,ascending=False).head(20)
# Out:
#     signal   req  value     oc     strategy portfolio_type modeler_type  \
# 19    0.05  0.15  False  False  speculation      universal    universal
# 11    0.05  0.10  False  False  speculation      universal    universal
# 41    0.10  0.15  False  False  speculation      universal     industry
# 33    0.10  0.10  False  False  speculation      universal     industry
# 18    0.05  0.15  False  False  speculation      universal    universal
# 3     0.05  0.05  False  False  speculation      universal    universal
# 25    0.10  0.05  False  False  speculation      universal     industry
# 10    0.05  0.10  False  False  speculation      universal    universal
# 17    0.05  0.15  False  False  speculation      universal     industry
# 40    0.10  0.15  False  False  speculation      universal     industry
# 65    0.15  0.15  False  False  speculation      universal     industry
# 43    0.10  0.15  False  False  speculation      universal    universal
# 9     0.05  0.10  False  False  speculation      universal     industry
# 35    0.10  0.10  False  False  speculation      universal    universal
# 57    0.15  0.10  False  False  speculation      universal     industry
# 32    0.10  0.10  False  False  speculation      universal     industry
# 27    0.10  0.05  False  False  speculation      universal    universal
# 67    0.15  0.15  False  False  speculation      universal    universal
# 59    0.15  0.10  False  False  speculation      universal    universal
# 16    0.05  0.15  False  False  speculation      universal     industry
#
#    diversifier_type        pv
# 19         industry  1.117104
# 11         industry  1.102365
# 41         industry  1.099333
# 33         industry  1.089743
# 18            basic  1.070168
# 3          industry  1.064028
# 25         industry  1.062372
# 10            basic  1.053026
# 17         industry  1.049069
# 40            basic  1.040428
# 65         industry  1.040326
# 43         industry  1.038558
# 9          industry  1.038298
# 35         industry  1.035053
# 57         industry  1.031727
# 32            basic  1.031352
# 27         industry  1.020876
# 67         industry  1.019185
# 59         industry  1.014164
# 16            basic  1.012513

# %%
results = []
strategy = "speculation"
for modeler_type in complete["modeler_type"].unique():
    for diversifier_type in complete["diversifier_type"].unique():
        results.append(complete[(complete["strategy"]==strategy) & (complete["modeler_type"]==modeler_type) & (complete["diversifier_type"]==diversifier_type)].sort_values("pv",ascending=False).head(1))
backtest_report = pd.concat(results)
best_it = backtest_report[(backtest_report["strategy"]==strategy)].copy()
backtest_report
# Out:
#     signal   req  value     oc     strategy portfolio_type modeler_type  \
# 40    0.10  0.15  False  False  speculation      universal     industry
# 41    0.10  0.15  False  False  speculation      universal     industry
# 18    0.05  0.15  False  False  speculation      universal    universal
# 19    0.05  0.15  False  False  speculation      universal    universal
#
#    diversifier_type        pv
# 40            basic  1.040428
# 41         industry  1.099333
# 18            basic  1.070168
# 19         industry  1.117104

# %%
sp5["GICS Sector"].unique()
# Out:
# array(['Industrials', 'Health Care', 'Information Technology',
#        'Communication Services', 'Consumer Staples',
#        'Consumer Discretionary', 'Utilities', 'Financials', 'Materials',
#        'Real Estate', 'Energy'], dtype=object)

# %%
# all_portfolios = pt.copy()
# for modeler_type in complete["modeler_type"].unique():
#     for diversifier_type in complete["diversifier_type"].unique():
#         a_it = best_it[(best_it["modeler_type"]==modeler_type) & (best_it["diversifier_type"]==diversifier_type)]
#     iteration_trades = t.copy()
#     iteration_analysis = []
#     for col in a_it.columns:
#         if col != "pv":
#             param = row[1][col]
#             iteration_trades = iteration_trades[(iteration_trades[col]==param)]
#     positions = int(iteration_trades["position"].max())
#     iteration_trades["delta"] = iteration_trades["delta"] + 1
#     pivoted = iteration_trades.pivot_table(index="sell_date",columns="position",values="delta").fillna(1).reset_index()
#     for i in range(10):
#         if i not in pivoted.columns:
#             pivoted[i] = 1
#     pivoted["pv"] = [sum([row[1][column] * 0.1 for column in range(10)]) for row in pivoted.iterrows()]
#     pivoted["pv"] = pivoted[["pv"]].cumprod()
#     bench = pd.read_csv("./csv_files/FED/SPY.csv")
#     bench = p.column_date_processing(bench)
#     close_col = "adjclose"   
#     ds = bench[(bench["date"]<=endDate) &(bench["date"]>=startDate)].merge(pivoted[["sell_date","pv"]].rename(columns={"sell_date":"date"}),on="date",how="right").sort_values("date")
#     ds["bench_prog"] = (ds[close_col] - ds[close_col].iloc[0]) / ds[close_col].iloc[0] + 1
#     figure, axes = plt.subplots(figsize=(16, 8))
#     axes.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
#     axes.plot(ds["date"],
#              ds["bench_prog"])
#     axes.plot(ds["date"],
#              ds["pv"])
#     plt.title(f"{modeler_type}_{diversifier_type}_{positions}")
#     plt.show()

# %%
ds
# Out:
#         date        open        high         low       close    adjclose  \
# 0 2016-02-12         NaN         NaN         NaN         NaN         NaN
# 1 2018-11-16  271.790009  274.750000  271.209991  273.730011  254.607559
# 2 2019-03-29  282.390015  282.839996  281.140015  282.480011  265.444702
# 3 2019-08-09  292.579987  293.239990  289.649994  291.619995  275.366333
# 4 2019-08-16  286.480011  289.329987  284.709991  288.850006  272.750671
# 5 2019-10-25  299.739990  302.200012  299.679993  301.600006  286.105255
# 6 2019-11-22  311.089996  311.239990  309.850006  310.959991  294.984314
# 7 2022-05-13  396.709991  403.179993  395.609985  401.720001  396.534882
#
#         volume    year  quarter  week        pv  bench_prog
# 0          NaN     NaN      NaN   NaN  1.002628         NaN
# 1  126668000.0  2018.0      4.0  46.0  0.997139         NaN
# 2   82186800.0  2019.0      1.0  13.0  0.996996         NaN
# 3   93730000.0  2019.0      3.0  32.0  0.990401         NaN
# 4   83018300.0  2019.0      3.0  33.0  0.991068         NaN
# 5   45205400.0  2019.0      4.0  43.0  0.994822         NaN
# 6   44850200.0  2019.0      4.0  47.0  0.997006         NaN
# 7  104174400.0  2022.0      2.0  19.0  1.005549         NaN

# %%
industry_report = []
stock_report = []
all_trades = t.copy()
for modeler_type in complete["modeler_type"].unique():
    for diversifier_type in complete["diversifier_type"].unique():
        a_it = best_it[(best_it["modeler_type"]==modeler_type) & (best_it["diversifier_type"]==diversifier_type)]
        best_trades = all_trades.copy()
        for col in parameter_columns:
            best_trades = best_trades[best_trades[col]==a_it[col].item()]
        best_trades = best_trades[(best_trades["sell_date"]>=startDate) & (best_trades["sell_date"]<=endDate)]
        reporting = best_trades.merge(sp5.rename(columns={"Symbol":"ticker"}),on="ticker",how="left").sort_values("delta",ascending=False)[["date","sell_date","position","holding","projected_delta","value","delta","ticker","Security","GICS Sector","GICS Sub-Industry","modeler_type","diversifier_type","sell_price","buy_price"]]
        stock_report.append(reporting.sort_values("delta",ascending=False))
        reporting["delta"] = reporting["delta"] + 1
        reporting["year"] = [x.year for x in reporting["date"]]
        reporting["quarter"] = [x.quarter for x in reporting["date"]]
        reporting["modeler_type"] = modeler_type
        reporting["diversifier_type"] = diversifier_type
        ir = reporting.groupby(["year","GICS Sector","GICS Sub-Industry","modeler_type","diversifier_type"]).agg({"delta":np.prod,"buy_price":"mean","projected_delta":"mean","holding":"mean"}).sort_values("delta",ascending=False)
        ir["strategy"] = strategy
        industry_report.append(ir)

# %%
stock_trades = pd.concat(stock_report).sort_values(["modeler_type","diversifier_type","date"],ascending=True)
stock_trades[stock_trades["diversifier_type"]=="industry"].head(10)
# Out:
#         date  sell_date  position  holding  projected_delta  value     delta  \
# 0 2016-06-08 2016-06-10         0        2         0.115131  False -0.017065
# 1 2016-07-06 2016-07-08         0        2         0.130104  False  0.039334
# 2 2016-07-19 2016-07-22         0        3         0.159824  False -0.010386
# 3 2016-07-26 2016-07-29         0        3         0.141997  False  0.029227
# 4 2016-08-02 2016-08-05         0        3         0.182235  False  0.006276
# 5 2016-08-23 2016-08-26         0        3         0.183536  False -0.015828
# 6 2016-08-30 2016-09-02         0        3         0.184394  False -0.027173
# 7 2016-09-21 2016-09-23         0        2         0.215735  False -0.012550
# 8 2016-09-27 2016-09-30         0        3         0.211995  False  0.014678
# 9 2016-10-04 2016-10-07         0        3         0.208916  False  0.005243
#
#   ticker Security  GICS Sector      GICS Sub-Industry modeler_type  \
# 0   ABMD  Abiomed  Health Care  Health Care Equipment     industry
# 1   ABMD  Abiomed  Health Care  Health Care Equipment     industry
# 2   ABMD  Abiomed  Health Care  Health Care Equipment     industry
# 3   ABMD  Abiomed  Health Care  Health Care Equipment     industry
# 4   ABMD  Abiomed  Health Care  Health Care Equipment     industry
# 5   ABMD  Abiomed  Health Care  Health Care Equipment     industry
# 6   ABMD  Abiomed  Health Care  Health Care Equipment     industry
# 7   ABMD  Abiomed  Health Care  Health Care Equipment     industry
# 8   ABMD  Abiomed  Health Care  Health Care Equipment     industry
# 9   ABMD  Abiomed  Health Care  Health Care Equipment     industry
#
#   diversifier_type  sell_price  buy_price
# 0         industry      102.53     104.31
# 1         industry      114.15     109.83
# 2         industry      116.25     117.47
# 3         industry      117.97     114.62
# 4         industry      120.25     119.50
# 5         industry      118.76     120.67
# 6         industry      117.43     120.71
# 7         industry      123.53     125.10
# 8         industry      128.58     126.72
# 9         industry      128.47     127.80

# %%
stock_trades = pd.concat(stock_report).sort_values(["modeler_type","diversifier_type","holding"],ascending=False)
stock_trades.head(10)
# Out:
#           date  sell_date  position  holding  projected_delta  value  \
# 107 2020-12-22 2021-01-08         0       17         0.058249  False
# 84  2020-04-07 2020-04-17         0       10         0.069079  False
# 129 2021-12-21 2021-12-31         0       10         0.052941  False
# 36  2018-03-27 2018-04-06         0       10         0.210781  False
# 1   2016-03-23 2016-04-01         0        9         0.052658  False
# 78  2019-10-29 2019-11-01         0        3         0.051627  False
# 31  2018-02-13 2018-02-16         0        3         0.081176  False
# 89  2020-06-02 2020-06-05         0        3         0.054222  False
# 95  2020-08-25 2020-08-28         0        3         0.146981  False
# 41  2018-05-08 2018-05-11         0        3         0.293478  False
#
#         delta ticker    Security             GICS Sector  \
# 107  0.095500   ABMD     Abiomed             Health Care
# 84   0.078275   ADBE  Adobe Inc.  Information Technology
# 129  0.031450   ADBE  Adobe Inc.  Information Technology
# 36  -0.031077   ABMD     Abiomed             Health Care
# 1    0.032941   ABMD     Abiomed             Health Care
# 78   0.150000   ABMD     Abiomed             Health Care
# 31   0.145559   ABMD     Abiomed             Health Care
# 89   0.104670   ABMD     Abiomed             Health Care
# 95   0.084275   ADBE  Adobe Inc.  Information Technology
# 41   0.072244   ABMD     Abiomed             Health Care
#
#          GICS Sub-Industry modeler_type diversifier_type  sell_price  \
# 107  Health Care Equipment    universal         industry    324.0600
# 84    Application Software    universal         industry    344.1100
# 129   Application Software    universal         industry    567.0600
# 36   Health Care Equipment    universal         industry    286.2200
# 1    Health Care Equipment    universal         industry     96.5800
# 78   Health Care Equipment    universal         industry    211.4965
# 31   Health Care Equipment    universal         industry    267.7400
# 89   Health Care Equipment    universal         industry    249.8100
# 95    Application Software    universal         industry    516.4400
# 41   Health Care Equipment    universal         industry    372.6800
#
#      buy_price
# 107     295.81
# 84      319.13
# 129     549.77
# 36      295.40
# 1        93.50
# 78      183.91
# 31      233.72
# 89      226.14
# 95      476.30
# 41      347.57

# %%
stock_trades = pd.concat(stock_report).sort_values(["modeler_type","diversifier_type","delta"],ascending=True)
stock_trades.head(10)
# Out:
#           date  sell_date  position  holding  projected_delta  value  \
# 17  2016-10-25 2016-10-28         0        3         0.200558  False
# 133 2018-07-24 2018-07-27         0        3         0.344605  False
# 250 2021-11-30 2021-12-03         0        3         0.222351  False
# 159 2018-10-23 2018-10-26         0        3         0.269127  False
# 253 2021-12-15 2021-12-17         1        2         0.142454  False
# 212 2020-09-02 2020-09-04         1        2         0.282051  False
# 274 2022-09-20 2022-09-23         0        3         0.192528  False
# 265 2022-06-15 2022-06-17         1        2         0.138660  False
# 157 2018-10-17 2018-10-19         1        2         0.301871  False
# 87  2017-11-29 2017-12-01         3        2         0.255765  False
#
#         delta ticker             Security             GICS Sector  \
# 17  -0.163044   ABMD              Abiomed             Health Care
# 133 -0.143258   ABMD              Abiomed             Health Care
# 250 -0.103216   ADBE           Adobe Inc.  Information Technology
# 159 -0.097897   ABMD              Abiomed             Health Care
# 253 -0.094688   ADBE           Adobe Inc.  Information Technology
# 212 -0.068207   ADBE           Adobe Inc.  Information Technology
# 274 -0.065041    ADM                  ADM        Consumer Staples
# 265 -0.064836    ADM                  ADM        Consumer Staples
# 157 -0.063224   ABMD              Abiomed             Health Care
# 87  -0.060785   ATVI  Activision Blizzard  Communication Services
#
#                   GICS Sub-Industry modeler_type diversifier_type  sell_price  \
# 17            Health Care Equipment     industry            basic  105.130000
# 133           Health Care Equipment     industry            basic  369.170000
# 250            Application Software     industry            basic  616.530000
# 159           Health Care Equipment     industry            basic  330.350000
# 253            Application Software     industry            basic  556.640000
# 212            Application Software     industry            basic  491.940000
# 274           Agricultural Products     industry            basic   81.305957
# 265           Agricultural Products     industry            basic   76.630212
# 157           Health Care Equipment     industry            basic  362.420000
# 87   Interactive Home Entertainment     industry            basic   60.100691
#
#       buy_price
# 17   125.610000
# 133  430.900000
# 250  687.490000
# 159  366.200000
# 253  614.860000
# 212  527.950000
# 274   86.962024
# 265   81.943082
# 157  386.880000
# 87    63.990358

# %%
pd.concat(industry_report).sort_values("delta",ascending=False).reset_index().head(20)
# Out:
#     year             GICS Sector      GICS Sub-Industry modeler_type  \
# 0   2018             Health Care  Health Care Equipment    universal
# 1   2018             Health Care  Health Care Equipment    universal
# 2   2017  Information Technology   Application Software     industry
# 3   2017  Information Technology   Application Software     industry
# 4   2021  Information Technology   Application Software     industry
# 5   2020  Information Technology   Application Software    universal
# 6   2017             Health Care  Health Care Equipment     industry
# 7   2019             Health Care  Health Care Equipment    universal
# 8   2019             Health Care  Health Care Equipment    universal
# 9   2020             Health Care  Health Care Equipment     industry
# 10  2018             Health Care  Health Care Equipment     industry
# 11  2020             Health Care  Health Care Equipment    universal
# 12  2018             Health Care  Health Care Equipment     industry
# 13  2020  Information Technology   Application Software     industry
# 14  2017             Health Care  Health Care Equipment     industry
# 15  2022  Information Technology   Application Software    universal
# 16  2020             Health Care  Health Care Equipment     industry
# 17  2017             Health Care  Health Care Equipment    universal
# 18  2021  Information Technology   Application Software    universal
# 19  2016             Health Care  Health Care Equipment    universal
#
#    diversifier_type     delta   buy_price  projected_delta   holding  \
# 0          industry  1.769192  340.131579         0.247036  3.078947
# 1             basic  1.458176  342.181556         0.250103  2.888889
# 2             basic  1.385319  151.406471         0.190098  3.029412
# 3          industry  1.327320  149.716667         0.185028  2.541667
# 4          industry  1.288804  615.431765         0.162736  2.176471
# 5          industry  1.260753  450.304706         0.124382  3.294118
# 6             basic  1.203106  165.457667         0.216239  2.633333
# 7          industry  1.186758  229.383333         0.083539  3.000000
# 8             basic  1.186758  229.383333         0.083539  3.000000
# 9             basic  1.165074  258.030000         0.119003  7.000000
# 10            basic  1.161504  350.432857         0.255668  2.904762
# 11         industry  1.145121  216.242361         0.066629  4.222222
# 12         industry  1.132242  353.426111         0.258308  2.666667
# 13         industry  1.110632  453.713810         0.199996  3.904762
# 14         industry  1.108327  170.115000         0.229925  2.000000
# 15            basic  1.105270  298.570000         0.077181  2.000000
# 16         industry  1.104670  226.140000         0.128282  3.000000
# 17            basic  1.089109  180.674118         0.139828  2.588235
# 18         industry  1.083021  632.997647         0.163851  3.294118
# 19            basic  1.076141  106.490000         0.063609  3.600000
#
#        strategy
# 0   speculation
# 1   speculation
# 2   speculation
# 3   speculation
# 4   speculation
# 5   speculation
# 6   speculation
# 7   speculation
# 8   speculation
# 9   speculation
# 10  speculation
# 11  speculation
# 12  speculation
# 13  speculation
# 14  speculation
# 15  speculation
# 16  speculation
# 17  speculation
# 18  speculation
# 19  speculation

# %%
if save_parameters:
    for portfolio in fund.portfolios:
        portfolio_type = portfolio["portfolio_type"]
        modeler_type = portfolio["modeler_type"]
        diversifier_type = portfolio["diversifier_type"]
        strategy = portfolio["portfolio_class"].strat_class.name
        optimal = complete[(complete["strategy"]==strategy) & (complete["modeler_type"]==modeler_type) & (complete["diversifier_type"]==diversifier_type)].sort_values("pv",ascending=False).head(1)
        strat_db = ADatabase(f"universal_financial_{modeler_type}_{diversifier_type}_{fund.state.value}")
        strat_db.connect()
        strat_db.drop("optimal_parameters")
        strat_db.store("optimal_parameters",optimal[parameter_columns])
        strat_db.disconnect()
