# %%
from datetime import datetime
from fund.fund import Fund
from pricer.pricer import Pricer as pricer_list
from ranker.ranker import Ranker as ranker_list
from classifier.classifier import Classifier as classifier_list
from portfolio.aportfolio import APortfolio
from parameters.parameters import Parameters 
import pandas as pd
from returns.products import Products
from processor.processor import Processor as p
from returns.products import Products
from database.market import Market

# %%
portfolio_ii = APortfolio(pricer_list.WEEKLY_STOCK_ROLLING
                           ,classifier_list.NONE
                          ,ranker_list.NONE)
# portfolio_v = APortfolio(pricer_list.WEEKLY_CRYPTO_WINDOW
#                           ,classifier_list.NONE
#                           ,ranker_list.NONE)
portfolios = []
portfolios.append(portfolio_ii)
# portfolios.append(portfolio_v)

# %%
backtest_start_date = datetime(2001,1,1)
backtest_end_date  = datetime(2023,1,1)
current_start_date = datetime(2023,1,1)
current_end_date = datetime.now()
week = datetime.now().isocalendar()[1]

# %%
fund = Fund(portfolios,backtest_start_date,backtest_end_date,current_start_date)
market = Market()

# %%
fund.initialize_portfolios()
fund.initialize_backtesters()

# %%
fund.reset()
recs = fund.pull_recommendation()

# %%
analysis = pd.concat(recs)

# %%
analysis[analysis["week"]==week].sort_values(["week","weekly_delta"],ascending=False).head(20)
# Out:
#       year  week ticker                        Security  \
# 65    2023    28    CCL                        Carnival
# 106   2023    28   NCLH  Norwegian Cruise Line Holdings
# 39    2023    28   NVDA                          Nvidia
# 158   2023    28    RCL           Royal Caribbean Group
# 243   2023    28   TSLA                     Tesla, Inc.
# 381   2023    28    DAL                 Delta Air Lines
# 61    2023    28   META                  Meta Platforms
# 225   2023    28   AVGO                   Broadcom Inc.
# 322   2023    28   ADBE                      Adobe Inc.
# 472   2023    28   NFLX                         Netflix
# 659   2023    28    AAL         American Airlines Group
# 707   2023    28    ALK                Alaska Air Group
# 210   2023    28    PHM                      PulteGroup
# 444   2023    28   GNRC                         Generac
# 551   2023    28   ISRG              Intuitive Surgical
# 826   2023    28    LYV       Live Nation Entertainment
# 753   2023    28      F              Ford Motor Company
# 1026  2023    28    LUV              Southwest Airlines
# 419   2023    28   FTNT                        Fortinet
# 1088  2023    28    UAL        United Airlines Holdings
#
#                  GICS Sector  position  weekly_delta  weekly_delta_sign  \
# 65    Consumer Discretionary         0      0.411187                1.0
# 106   Consumer Discretionary         1      0.320246                1.0
# 39    Information Technology         2      0.283941                1.0
# 158   Consumer Discretionary         3      0.269239                1.0
# 243   Consumer Discretionary         4      0.259194                1.0
# 381              Industrials         5      0.237729                1.0
# 61    Communication Services         6      0.229440                1.0
# 225   Information Technology         7      0.224196                1.0
# 322   Information Technology         8      0.219219                1.0
# 472   Communication Services         9      0.198547                1.0
# 659              Industrials        10      0.193452                1.0
# 707              Industrials        11      0.180721                1.0
# 210   Consumer Discretionary        12      0.179077                1.0
# 444              Industrials        13      0.178350                1.0
# 551              Health Care        14      0.175043                1.0
# 826   Communication Services        15      0.174782                1.0
# 753   Consumer Discretionary        16      0.171340                1.0
# 1026             Industrials        17      0.169023                1.0
# 419   Information Technology        18      0.155260                1.0
# 1088             Industrials        19      0.154375                1.0
#
#         portfolio
# 65    wsr_n_n_b_r
# 106   wsr_n_n_b_r
# 39    wsr_n_n_b_r
# 158   wsr_n_n_b_r
# 243   wsr_n_n_b_r
# 381   wsr_n_n_b_r
# 61    wsr_n_n_b_r
# 225   wsr_n_n_b_r
# 322   wsr_n_n_b_r
# 472   wsr_n_n_b_r
# 659   wsr_n_n_b_r
# 707   wsr_n_n_b_r
# 210   wsr_n_n_b_r
# 444   wsr_n_n_b_r
# 551   wsr_n_n_b_r
# 826   wsr_n_n_b_r
# 753   wsr_n_n_b_r
# 1026  wsr_n_n_b_r
# 419   wsr_n_n_b_r
# 1088  wsr_n_n_b_r
